# %% [markdown]
# ## ImdbInfo

# %%
from imdbinfo import search_title

# %%
title = "Chicago"
results = search_title(title)
results

# %% [markdown]
# ## Cinemagoer

# %%
import imdb

# %%
ia = imdb.Cinemagoer()

# %%
all_series = ia.search_movie(title)
all_series
# Out:
# []

# %%
ia.search_person('angelina')
# Out:
# []
